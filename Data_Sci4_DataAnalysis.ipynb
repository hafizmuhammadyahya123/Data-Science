# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizmuhammadyahya123/Data-Science/blob/main/Data_Sci4_DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('/content/SaleData (1).xlsx')
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel._base:
#
# ...

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.bar(x = df['OrderDate'],height=df['Unit_price'])
# Out:
# <BarContainer object of 45 artists>

# %%
df.plot.bar(x='OrderDate',y='Unit_price',rot=0)
# Out:
# <Axes: xlabel='OrderDate'>

# %%
fig , ax = plt.subplots()
p = ax.bar(x = df['OrderDate'],height=df['Unit_price'])
ax.bar_label(p,label_type='center')
# Out:
# [Text(0, 0, '1198'),
#  Text(0, 0, '500'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '225'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '500'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '500'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '500'),
#  Text(0, 0, '500'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '125'),
#  Text(0, 0, '58.5'),
#  Text(0, 0, '500'),
#  Text(0, 0, '225'),
#  Text(0, 0, '225'),
#  Text(0, 0, '58.5'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '58.5'),
#  Text(0, 0, '500'),
#  Text(0, 0, '500'),
#  Text(0, 0, '500'),
#  Text(0, 0, '500'),
#  Text(0, 0, '58.5'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '225'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '500'),
#  Text(0, 0, '125'),
#  Text(0, 0, '58.5'),
#  Text(0, 0, '58.5'),
#  Text(0, 0, '58.5'),
#  Text(0, 0, '125'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '225'),
#  Text(0, 0, '500'),
#  Text(0, 0, '1198'),
#  Text(0, 0, '500'),
#  Text(0, 0, '500'),
#  Text(0, 0, '500'),
#  Text(0, 0, '1125'),
# ...

# %%
type(df['OrderDate'])
# Out:
# pandas.core.series.Series

# %%
s = df['OrderDate']
s
# Out:
# 0    2018-01-06
# 1    2018-01-23
# 2    2018-02-09
# 3    2018-02-26
# 4    2018-03-15
# 5    2018-04-01
# 6    2018-04-18
# 7    2018-05-05
# 8    2018-05-22
# 9    2018-06-08
# 10   2018-06-25
# 11   2018-07-12
# 12   2018-07-29
# 13   2018-08-15
# 14   2018-09-01
# 15   2018-09-18
# 16   2018-10-05
# 17   2018-10-22
# 18   2018-11-08
# 19   2018-11-25
# 20   2018-12-12
# 21   2018-12-29
# 22   2019-01-15
# 23   2019-02-01
# 24   2019-02-18
# 25   2019-03-07
# 26   2019-03-24
# 27   2019-04-10
# 28   2019-04-27
# 29   2019-05-14
# 30   2019-05-31
# 31   2019-06-17
# 32   2019-07-04
# 33   2019-07-21
# 34   2019-08-07
# 35   2019-08-24
# 36   2019-09-10
# 37   2019-09-27
# 38   2019-10-14
# 39   2019-10-31
# 40   2019-11-17
# 41   2019-12-04
# 42   2019-12-21
# 43          NaT
# 44          NaT
# Name: OrderDate, dtype: datetime64[ns]

# %%
df.index = s #first column row ka index k jagah bhi or first column bhi
df
# Out:
#              Region  Manager   SalesMan          Item   Units  Unit_price  \
# OrderDate
# 2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
from re import A
df.drop(['Region'],axis=1,inplace=True)
df
# Out:
#             Manager   SalesMan          Item   Units  Unit_price   Sale_amt
# OrderDate
# 2018-01-06   Martha  Alexander    Television   95.00    1198.000  113810.00
# 2018-01-23  Hermann     Shelli  Home Theater   50.00     500.000   25000.00
# 2018-02-09  Hermann       Luis    Television   36.00    1198.000   43128.00
# 2018-02-26  Timothy      David    Cell Phone   27.00     225.000    6075.00
# 2018-03-15  Timothy    Stephen    Television   56.00    1198.000   67088.00
# 2018-04-01   Martha  Alexander  Home Theater   60.00     500.000   30000.00
# 2018-04-18   Martha     Steven    Television   75.00    1198.000   89850.00
# 2018-05-05  Hermann       Luis    Television   90.00    1198.000  107820.00
# 2018-05-22  Douglas    Michael    Television   32.00    1198.000   38336.00
# 2018-06-08   Martha  Alexander  Home Theater   60.00     500.000   30000.00
# 2018-06-25  Hermann      Sigal    Television   90.00    1198.000  107820.00
# ...

# %%
df.iloc[:,0]
# Out:
# OrderDate
# 2018-01-06     Martha
# 2018-01-23    Hermann
# 2018-02-09    Hermann
# 2018-02-26    Timothy
# 2018-03-15    Timothy
# 2018-04-01     Martha
# 2018-04-18     Martha
# 2018-05-05    Hermann
# 2018-05-22    Douglas
# 2018-06-08     Martha
# 2018-06-25    Hermann
# 2018-07-12     Martha
# 2018-07-29    Douglas
# 2018-08-15     Martha
# 2018-09-01    Douglas
# 2018-09-18     Martha
# 2018-10-05    Hermann
# 2018-10-22     Martha
# 2018-11-08    Douglas
# 2018-11-25    Hermann
# 2018-12-12    Douglas
# 2018-12-29    Douglas
# 2019-01-15    Timothy
# 2019-02-01    Douglas
# 2019-02-18     Martha
# 2019-03-07    Timothy
# 2019-03-24    Hermann
# 2019-04-10     Martha
# 2019-04-27     Martha
# 2019-05-14    Timothy
# 2019-05-31    Timothy
# 2019-06-17    Hermann
# 2019-07-04     Martha
# 2019-07-21    Hermann
# 2019-08-07    Hermann
# 2019-08-24    Timothy
# 2019-09-10    Timothy
# 2019-09-27    Timothy
# 2019-10-14    Douglas
# 2019-10-31     Martha
# 2019-11-17    Hermann
# ...

# %%
df.iloc[:,2]
# Out:
# OrderDate
# 2018-01-06      Television
# 2018-01-23    Home Theater
# 2018-02-09      Television
# 2018-02-26      Cell Phone
# 2018-03-15      Television
# 2018-04-01    Home Theater
# 2018-04-18      Television
# 2018-05-05      Television
# 2018-05-22      Television
# 2018-06-08    Home Theater
# 2018-06-25      Television
# 2018-07-12    Home Theater
# 2018-07-29    Home Theater
# 2018-08-15      Television
# 2018-09-01            Desk
# 2018-09-18     Video Games
# 2018-10-05    Home Theater
# 2018-10-22      Cell Phone
# 2018-11-08      Cell Phone
# 2018-11-25     Video Games
# 2018-12-12      Television
# 2018-12-29     Video Games
# 2019-01-15    Home Theater
# 2019-02-01    Home Theater
# 2019-02-18    Home Theater
# 2019-03-07    Home Theater
# 2019-03-24     Video Games
# 2019-04-10      Television
# 2019-04-27      Cell Phone
# 2019-05-14      Television
# 2019-05-31    Home Theater
# 2019-06-17            Desk
# 2019-07-04     Video Games
# 2019-07-21     Video Games
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-06', '2018-01-23', '2018-02-09', '2018-02-26',
#                '2018-03-15', '2018-04-01', '2018-04-18', '2018-05-05',
#                '2018-05-22', '2018-06-08', '2018-06-25', '2018-07-12',
#                '2018-07-29', '2018-08-15', '2018-09-01', '2018-09-18',
#                '2018-10-05', '2018-10-22', '2018-11-08', '2018-11-25',
#                '2018-12-12', '2018-12-29', '2019-01-15', '2019-02-01',
#                '2019-02-18', '2019-03-07', '2019-03-24', '2019-04-10',
#                '2019-04-27', '2019-05-14', '2019-05-31', '2019-06-17',
#                '2019-07-04', '2019-07-21', '2019-08-07', '2019-08-24',
#                '2019-09-10', '2019-09-27', '2019-10-14', '2019-10-31',
#                '2019-11-17', '2019-12-04', '2019-12-21',        'NaT',
#                       'NaT'],
#               dtype='datetime64[ns]', name='OrderDate', freq=None)

# %%
df.index.name=''
df
# Out:
#             Manager   SalesMan          Item   Units  Unit_price   Sale_amt
#
# 2018-01-06   Martha  Alexander    Television   95.00    1198.000  113810.00
# 2018-01-23  Hermann     Shelli  Home Theater   50.00     500.000   25000.00
# 2018-02-09  Hermann       Luis    Television   36.00    1198.000   43128.00
# 2018-02-26  Timothy      David    Cell Phone   27.00     225.000    6075.00
# 2018-03-15  Timothy    Stephen    Television   56.00    1198.000   67088.00
# 2018-04-01   Martha  Alexander  Home Theater   60.00     500.000   30000.00
# 2018-04-18   Martha     Steven    Television   75.00    1198.000   89850.00
# 2018-05-05  Hermann       Luis    Television   90.00    1198.000  107820.00
# 2018-05-22  Douglas    Michael    Television   32.00    1198.000   38336.00
# 2018-06-08   Martha  Alexander  Home Theater   60.00     500.000   30000.00
# 2018-06-25  Hermann      Sigal    Television   90.00    1198.000  107820.00
# ...
